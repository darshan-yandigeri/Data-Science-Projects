# %% [markdown]
# # Project: Churn prediction for telecommunication business

# %% [markdown]
# # 1. Set Working Directory

# %%
import os

os.chdir('S:\Data Science Projects\Data-Science-Projects\Telecom-Churn-Analysis')

# %% [markdown]
# # 2. Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Import Data

# %%
# Import train dataset

df_train = pd.read_csv('churnTrain.csv')

df_train.head(2)
# Out:
#   State  Account_Length  Area_Code  Phone_No International_Plan  \
# 0    KS             128        415   3824657                 no
# 1    OH             107        415   3717191                 no
#
#   Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0             yes                 25              265.1              110
# 1             yes                 26              161.6              123
#
#    Total_Day_charge  ...    Total_Eve_Calls  Total_Eve_Charge  \
# 0             45.07  ...                 99             16.78
# 1             27.47  ...                103             16.62
#
#    Total_Night_Minutes  Total_Night_Calls  Total_Night_Charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total_Intl_Minutes  Total_Intl_Calls  Total_Intl_Charge  No_CS_Calls  Churn
# 0                10.0                 3                2.7            1  False
# 1                13.7                 3                3.7            1  False
#
# [2 rows x 21 columns]

# %%
df_train.shape
# Out:
# (3333, 21)

# %%
# Import test dataset

df_test = pd.read_csv('churnTest.csv')

df_test.head(2)
# Out:
#   State  Account_Length  Area_Code  Phone_No International_Plan  \
# 0    HI           101.0      510.0   3548815                 no
# 1    MT           137.0      510.0   3817211                 no
#
#   Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0              no                  0               70.9            123.0
# 1              no                  0              223.6             86.0
#
#    Total_Day_charge  Total_Eve_Minutes  Total_Eve_Calls  Total_Eve_Charge  \
# 0             12.05              211.9             73.0             18.01
# 1             38.01              244.8            139.0             20.81
#
#    Total_Night_Minutes  Total_Night_Calls  Total_Night_Charge  \
# 0                236.0               73.0               10.62
# 1                 94.2               81.0                4.24
#
#    Total_Intl_Minutes  Total_Intl_Calls  Total_Intl_Charge  No_CS_Calls
# 0                10.6               3.0               2.86            3
# 1                 9.5               7.0               2.57            0

# %%
df_test.shape
# Out:
# (425, 20)

# %% [markdown]
# # 4. Data Exploration

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# State                  3333 non-null object
# Account_Length         3333 non-null int64
# Area_Code              3333 non-null int64
# Phone_No               3333 non-null int64
# International_Plan     3333 non-null object
# Voice_Mail_Plan        3333 non-null object
# No_Vmail_Messages      3333 non-null int64
# Total_Day_minutes      3333 non-null float64
# Total_Day_Calls        3333 non-null int64
# Total_Day_charge       3333 non-null float64
# Total_Eve_Minutes      3333 non-null float64
# Total_Eve_Calls        3333 non-null int64
# Total_Eve_Charge       3333 non-null float64
# Total_Night_Minutes    3333 non-null float64
# Total_Night_Calls      3333 non-null int64
# Total_Night_Charge     3333 non-null float64
# Total_Intl_Minutes     3333 non-null float64
# Total_Intl_Calls       3333 non-null int64
# Total_Intl_Charge      3333 non-null float64
# No_CS_Calls            3333 non-null int64
# Churn                  3333 non-null bool
# dtypes: bool(1), float64(8), int64(9), object(3)
# memory usage: 524.1+ KB

# %%
# Check for Null Values

df_train.isna().sum()
# Out:
# State                  0
# Account_Length         0
# Area_Code              0
# Phone_No               0
# International_Plan     0
# Voice_Mail_Plan        0
# No_Vmail_Messages      0
# Total_Day_minutes      0
# Total_Day_Calls        0
# Total_Day_charge       0
# Total_Eve_Minutes      0
# Total_Eve_Calls        0
# Total_Eve_Charge       0
# Total_Night_Minutes    0
# Total_Night_Calls      0
# Total_Night_Charge     0
# Total_Intl_Minutes     0
# Total_Intl_Calls       0
# Total_Intl_Charge      0
# No_CS_Calls            0
# Churn                  0
# dtype: int64

# %% [markdown]
# No null values in any columns

# %%
ax = sns.countplot(x="Churn", data=df_train)

# %%
df_train.Churn.value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %% [markdown]
# ### Converting categorical variable to binary

# %%
df_train['Churn'] = df_train['Churn'].astype(str)

df_train['Churn'] = np.where(df_train['Churn']=="True", 1, 0)

df_train['International_Plan'] = df_train['International_Plan'].str.strip()

df_train['International_Plan'] = np.where(df_train['International_Plan']=="yes", 1, 0)

df_train['Voice_Mail_Plan'] = df_train['Voice_Mail_Plan'].str.strip()

df_train['Voice_Mail_Plan'] = np.where(df_train['Voice_Mail_Plan']=="yes", 1, 0)

df_train.head(2)
# Out:
#   State  Account_Length  Area_Code  Phone_No  International_Plan  \
# 0    KS             128        415   3824657                   0
# 1    OH             107        415   3717191                   0
#
#    Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0                1                 25              265.1              110
# 1                1                 26              161.6              123
#
#    Total_Day_charge  ...    Total_Eve_Calls  Total_Eve_Charge  \
# 0             45.07  ...                 99             16.78
# 1             27.47  ...                103             16.62
#
#    Total_Night_Minutes  Total_Night_Calls  Total_Night_Charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total_Intl_Minutes  Total_Intl_Calls  Total_Intl_Charge  No_CS_Calls  Churn
# 0                10.0                 3                2.7            1      0
# 1                13.7                 3                3.7            1      0
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Correlation matrix

# %%
df_train.corr()
# Out:
#                      Account_Length  Area_Code  Phone_No  International_Plan  \
# Account_Length             1.000000  -0.012463  0.004808            0.024735
# Area_Code                 -0.012463   1.000000 -0.014029            0.048551
# Phone_No                   0.004808  -0.014029  1.000000            0.019941
# International_Plan         0.024735   0.048551  0.019941            1.000000
# Voice_Mail_Plan            0.002918  -0.000747  0.030755            0.006006
# No_Vmail_Messages         -0.004628  -0.001994  0.022569            0.008745
# Total_Day_minutes          0.006216  -0.008264  0.012014            0.049396
# Total_Day_Calls            0.038470  -0.009646 -0.005812            0.003755
# Total_Day_charge           0.006214  -0.008264  0.012009            0.049398
# Total_Eve_Minutes         -0.006757   0.003580 -0.017710            0.019100
# Total_Eve_Calls            0.019260  -0.011886  0.003519            0.006114
# Total_Eve_Charge          -0.006745   0.003607 -0.017688            0.019106
# Total_Night_Minutes       -0.008955  -0.005825 -0.008047           -0.028905
# Total_Night_Calls         -0.013176   0.016522  0.014034            0.012451
# Total_Night_Charge        -0.008960  -0.005845 -0.008049           -0.028913
# Total_Intl_Minutes         0.009514  -0.018288 -0.010269            0.045871
# Total_Intl_Calls           0.020661  -0.024179 -0.017676            0.017366
# Total_Intl_Charge          0.009546  -0.018395 -0.010245            0.045780
# No_CS_Calls               -0.003796   0.027572  0.033847           -0.024522
# Churn                      0.016541   0.006174  0.005730            0.259852
#
#                      Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  \
# Account_Length              0.002918          -0.004628           0.006216
# Area_Code                  -0.000747          -0.001994          -0.008264
# Phone_No                    0.030755           0.022569           0.012014
# International_Plan          0.006006           0.008745           0.049396
# Voice_Mail_Plan             1.000000           0.956927          -0.001684
# No_Vmail_Messages           0.956927           1.000000           0.000778
# Total_Day_minutes          -0.001684           0.000778           1.000000
# Total_Day_Calls            -0.011086          -0.009548           0.006750
# Total_Day_charge           -0.001686           0.000776           1.000000
# Total_Eve_Minutes           0.021545           0.017562           0.007043
# Total_Eve_Calls            -0.006444          -0.005864           0.015769
# Total_Eve_Charge            0.021559           0.017578           0.007029
# Total_Night_Minutes         0.006079           0.007681           0.004323
# Total_Night_Calls           0.015553           0.007123           0.022972
# Total_Night_Charge          0.006064           0.007663           0.004300
# Total_Intl_Minutes         -0.001318           0.002856          -0.010155
# Total_Intl_Calls            0.007618           0.013957           0.008033
# Total_Intl_Charge          -0.001276           0.002884          -0.010092
# No_CS_Calls                -0.017824          -0.013263          -0.013423
# Churn                      -0.102148          -0.089728           0.205151
#
#                      Total_Day_Calls  Total_Day_charge  Total_Eve_Minutes  \
# Account_Length              0.038470          0.006214          -0.006757
# Area_Code                  -0.009646         -0.008264           0.003580
# Phone_No                   -0.005812          0.012009          -0.017710
# International_Plan          0.003755          0.049398           0.019100
# Voice_Mail_Plan            -0.011086         -0.001686           0.021545
# No_Vmail_Messages          -0.009548          0.000776           0.017562
# Total_Day_minutes           0.006750          1.000000           0.007043
# Total_Day_Calls             1.000000          0.006753          -0.021451
# Total_Day_charge            0.006753          1.000000           0.007050
# Total_Eve_Minutes          -0.021451          0.007050           1.000000
# Total_Eve_Calls             0.006462          0.015769          -0.011430
# Total_Eve_Charge           -0.021449          0.007036           1.000000
# Total_Night_Minutes         0.022938          0.004324          -0.012584
# Total_Night_Calls          -0.019557          0.022972           0.007586
# Total_Night_Charge          0.022927          0.004301          -0.012593
# Total_Intl_Minutes          0.021565         -0.010157          -0.011035
# Total_Intl_Calls            0.004574          0.008032           0.002541
# Total_Intl_Charge           0.021666         -0.010094          -0.011067
# No_CS_Calls                -0.018942         -0.013427          -0.012985
# Churn                       0.018459          0.205151           0.092796
#
#                      Total_Eve_Calls  Total_Eve_Charge  Total_Night_Minutes  \
# Account_Length              0.019260         -0.006745            -0.008955
# Area_Code                  -0.011886          0.003607            -0.005825
# Phone_No                    0.003519         -0.017688            -0.008047
# International_Plan          0.006114          0.019106            -0.028905
# Voice_Mail_Plan            -0.006444          0.021559             0.006079
# No_Vmail_Messages          -0.005864          0.017578             0.007681
# Total_Day_minutes           0.015769          0.007029             0.004323
# Total_Day_Calls             0.006462         -0.021449             0.022938
# Total_Day_charge            0.015769          0.007036             0.004324
# Total_Eve_Minutes          -0.011430          1.000000            -0.012584
# Total_Eve_Calls             1.000000         -0.011423            -0.002093
# Total_Eve_Charge           -0.011423          1.000000            -0.012592
# Total_Night_Minutes        -0.002093         -0.012592             1.000000
# Total_Night_Calls           0.007710          0.007596             0.011204
# Total_Night_Charge         -0.002056         -0.012601             0.999999
# Total_Intl_Minutes          0.008703         -0.011043            -0.015207
# Total_Intl_Calls            0.017434          0.002541            -0.012353
# Total_Intl_Charge           0.008674         -0.011074            -0.015180
# No_CS_Calls                 0.002423         -0.012987            -0.009288
# Churn                       0.009233          0.092786             0.035493
#
#                      Total_Night_Calls  Total_Night_Charge  \
# Account_Length               -0.013176           -0.008960
# Area_Code                     0.016522           -0.005845
# Phone_No                      0.014034           -0.008049
# International_Plan            0.012451           -0.028913
# Voice_Mail_Plan               0.015553            0.006064
# No_Vmail_Messages             0.007123            0.007663
# Total_Day_minutes             0.022972            0.004300
# Total_Day_Calls              -0.019557            0.022927
# Total_Day_charge              0.022972            0.004301
# Total_Eve_Minutes             0.007586           -0.012593
# Total_Eve_Calls               0.007710           -0.002056
# Total_Eve_Charge              0.007596           -0.012601
# Total_Night_Minutes           0.011204            0.999999
# Total_Night_Calls             1.000000            0.011188
# Total_Night_Charge            0.011188            1.000000
# Total_Intl_Minutes           -0.013605           -0.015214
# Total_Intl_Calls              0.000305           -0.012329
# Total_Intl_Charge            -0.013630           -0.015186
# No_CS_Calls                  -0.012802           -0.009277
# Churn                         0.006141            0.035496
#
#                      Total_Intl_Minutes  Total_Intl_Calls  Total_Intl_Charge  \
# Account_Length                 0.009514          0.020661           0.009546
# Area_Code                     -0.018288         -0.024179          -0.018395
# Phone_No                      -0.010269         -0.017676          -0.010245
# International_Plan             0.045871          0.017366           0.045780
# Voice_Mail_Plan               -0.001318          0.007618          -0.001276
# No_Vmail_Messages              0.002856          0.013957           0.002884
# Total_Day_minutes             -0.010155          0.008033          -0.010092
# Total_Day_Calls                0.021565          0.004574           0.021666
# Total_Day_charge              -0.010157          0.008032          -0.010094
# Total_Eve_Minutes             -0.011035          0.002541          -0.011067
# Total_Eve_Calls                0.008703          0.017434           0.008674
# Total_Eve_Charge              -0.011043          0.002541          -0.011074
# Total_Night_Minutes           -0.015207         -0.012353          -0.015180
# Total_Night_Calls             -0.013605          0.000305          -0.013630
# Total_Night_Charge            -0.015214         -0.012329          -0.015186
# Total_Intl_Minutes             1.000000          0.032304           0.999993
# Total_Intl_Calls               0.032304          1.000000           0.032372
# Total_Intl_Charge              0.999993          0.032372           1.000000
# No_CS_Calls                   -0.009640         -0.017561          -0.009675
# Churn                          0.068239         -0.052844           0.068259
#
#                      No_CS_Calls     Churn
# Account_Length         -0.003796  0.016541
# Area_Code               0.027572  0.006174
# Phone_No                0.033847  0.005730
# International_Plan     -0.024522  0.259852
# Voice_Mail_Plan        -0.017824 -0.102148
# No_Vmail_Messages      -0.013263 -0.089728
# Total_Day_minutes      -0.013423  0.205151
# Total_Day_Calls        -0.018942  0.018459
# Total_Day_charge       -0.013427  0.205151
# Total_Eve_Minutes      -0.012985  0.092796
# Total_Eve_Calls         0.002423  0.009233
# Total_Eve_Charge       -0.012987  0.092786
# Total_Night_Minutes    -0.009288  0.035493
# Total_Night_Calls      -0.012802  0.006141
# Total_Night_Charge     -0.009277  0.035496
# Total_Intl_Minutes     -0.009640  0.068239
# Total_Intl_Calls       -0.017561 -0.052844
# Total_Intl_Charge      -0.009675  0.068259
# No_CS_Calls             1.000000  0.208750
# Churn                   0.208750  1.000000

# %% [markdown]
# From above correlation matrix, variables International_Plan, Total_Day_minutes, Total_Day_charge & No_CS_Calls look to be highly correlated to Churn variable

# %%
# Plotting state-wise churned users

fig, ax = plt.subplots(figsize=(20, 10))

order = df_train.groupby(['State']).sum()['Churn'].sort_values(ascending=False).index.values

ax = sns.countplot(x="State", hue="Churn", data=df_train, order=order)

# %% [markdown]
# From above plot, State TX has highest churned uses and AK as least churned users

# %%
# Dropping categorical feature State

df_train.drop(columns=['State'], inplace=True)

# %% [markdown]
# # 5. Modelling

# %% [markdown]
# ## 5.1 Logistic Regression

# %%
# Separate the Feature and Target Variables

X_train = df_train.loc[:, df_train.columns != 'Churn']

y_train = df_train['Churn']
